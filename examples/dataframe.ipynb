# %%
import pandas as pd
from dyniclick.plot_utils import plot_click_feat, get_highest_probability
# %matplotlib notebook

# %%
df = pd.read_hdf("dataframe.h5")

# %%
df
# Out:
#                             amplitude       ipi  ipi_salience      tdoa  \
# click_time
# 2000-01-01 00:00:00.108019   0.004316  0.001948      0.281195  0.000426
# 2000-01-01 00:00:00.135477   0.014487  0.006979      0.132170  0.000353
# 2000-01-01 00:00:00.170935   0.003283  0.007865      0.416597 -0.000012
# 2000-01-01 00:00:00.299373   0.399615  0.002563      0.130696 -0.000022
# 2000-01-01 00:00:00.332873   0.011856  0.001708      0.182657  0.000259
# 2000-01-01 00:00:00.347352   0.268990  0.002115      0.113819  0.000103
# 2000-01-01 00:00:00.485425   0.001232  0.007979      0.178096  0.000103
# 2000-01-01 00:00:00.501269   0.253617  0.002604      0.184952 -0.000043
# 2000-01-01 00:00:00.557154   0.792097  0.003031      0.279124 -0.000001
# 2000-01-01 00:00:00.617977   0.785955  0.003042      0.267965  0.000009
# 2000-01-01 00:00:00.697665   0.333440  0.002531      0.193561 -0.000085
# 2000-01-01 00:00:00.725487   0.012862  0.005625      0.100569 -0.000116
# ...

# %%
plot_click_feat(df)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df_h = get_highest_probability(df, '1S', 0.5)

# %%
plot_click_feat(df_h)
# Out:
# <img src="data:image/png;base64,..." width="640">
